# %% [markdown]
# # Data Analysis with Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Reading "kaggle_survey_2020_responses.csv" file which contains the results of Kaggle's survey with its members for the year 2020 to a DataFrame.

# %%
survey = pd.read_csv("kaggle_survey_2020_responses.csv", skiprows = [1], low_memory=False)

# %%
survey.drop(survey.columns[0], axis=1, inplace=True)

# %%
survey.rename(columns={"Q1": "Age", "Q2": "Gender", "Q3": "Country", "Q4": "Education", "Q5": "Occupation", "Q6": "Coding Experience"}, inplace=True)
survey
# Out:
#          Age Gender                                            Country  \
# 0      35-39    Man                                           Colombia
# 1      30-34    Man                           United States of America
# 2      35-39    Man                                          Argentina
# 3      30-34    Man                           United States of America
# 4      30-34    Man                                              Japan
# ...      ...    ...                                                ...
# 20031  18-21    Man                                             Turkey
# 20032  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 20033  30-34    Man                                             Brazil
# 20034  22-24    Man                                              India
# 20035  22-24    Man                                           Pakistan
#
#                                                Education  \
# 0                                        Doctoral degree
# 1                                        Master’s degree
# 2                                      Bachelor’s degree
# 3                                        Master’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 20031  Some college/university study without earning ...
# 20032                                    Master’s degree
# 20033                                    Master’s degree
# 20034                                  Bachelor’s degree
# 20035                                    Master’s degree
#
#                       Occupation Coding Experience Q7_Part_1 Q7_Part_2  \
# 0                        Student        5-10 years    Python         R
# 1                  Data Engineer        5-10 years    Python         R
# 2              Software Engineer       10-20 years       NaN       NaN
# 3                 Data Scientist        5-10 years    Python       NaN
# 4              Software Engineer         3-5 years    Python       NaN
# ...                          ...               ...       ...       ...
# 20031                        NaN               NaN       NaN       NaN
# 20032     Currently not employed         20+ years    Python       NaN
# 20033         Research Scientist         < 1 years    Python       NaN
# 20034          Software Engineer         3-5 years    Python       NaN
# 20035  Machine Learning Engineer         < 1 years    Python       NaN
#
#       Q7_Part_3 Q7_Part_4  ...        Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4  \
# 0           SQL         C  ...                 NaN          NaN          NaN
# 1           SQL       NaN  ...                 NaN          NaN          NaN
# 2           NaN       NaN  ...                 NaN          NaN          NaN
# 3           SQL       NaN  ...                 NaN          NaN          NaN
# 4           NaN       NaN  ...                 NaN          NaN          NaN
# ...         ...       ...  ...                 ...          ...          ...
# 20031       NaN       NaN  ...                 NaN          NaN          NaN
# 20032       NaN       NaN  ...                 NaN          NaN          NaN
# 20033       NaN       NaN  ...                 NaN          NaN          NaN
# 20034       SQL         C  ...   Weights & Biases           NaN          NaN
# 20035       NaN       NaN  ...   Weights & Biases           NaN          NaN
#
#         Q35_B_Part_5 Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9  \
# 0       TensorBoard           NaN          NaN          NaN          NaN
# 1                NaN          NaN          NaN          NaN          NaN
# 2                NaN          NaN          NaN          NaN          NaN
# 3                NaN          NaN          NaN          NaN          NaN
# 4                NaN          NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...          ...
# 20031            NaN          NaN          NaN          NaN          NaN
# 20032            NaN          NaN          NaN          NaN          NaN
# 20033            NaN          NaN          NaN          NaN          NaN
# 20034   TensorBoard           NaN          NaN      Trains           NaN
# 20035            NaN          NaN          NaN      Trains           NaN
#
#       Q35_B_Part_10 Q35_B_OTHER
# 0               NaN         NaN
# 1               NaN         NaN
# 2              None         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 20031           NaN         NaN
# 20032          None         NaN
# 20033           NaN         NaN
# 20034           NaN         NaN
# 20035           NaN         NaN
#
# [20036 rows x 354 columns]

# %%
row_number = survey.shape[0]

survey.dropna(subset=['Education', 'Occupation', 'Coding Experience'], inplace=True)

new_row_number = survey.shape[0]

print(row_number - new_row_number, "rows deleted.")
# Out:
# 916 rows deleted.

# %%
print("Rows: {} Columns: {}".format(survey.shape[0], survey.shape[1]))
# Out:
# Rows: 19120 Columns: 354

# %% [markdown]
# #### Age interval distribution of the respondents.

# %%
survey['Age'].value_counts().plot(kind="pie", figsize=(8,8), autopct='%0.0f%%')
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# #### List of the number of respondents from Turkey by their level of Education.

# %%
survey_tr = survey.loc[survey['Country'] == "Turkey"]

survey_tr_edu = survey_tr['Education'].groupby(survey_tr['Education']).count()

survey_tr_edu
# Out:
# Education
# Bachelor’s degree                                                    129
# Doctoral degree                                                       50
# I prefer not to answer                                                 8
# Master’s degree                                                      111
# No formal education past high school                                   3
# Professional degree                                                    6
# Some college/university study without earning a bachelor’s degree     15
# Name: Education, dtype: int64

# %% [markdown]
# #### List of the most common Occupation name for each age range.

# %%
grouped = survey.groupby(['Age'])

df = grouped['Occupation'].apply(lambda x: x.mode())

df = df.droplevel(1)

df
# Out:
# Age
# 18-21           Student
# 22-24           Student
# 25-29           Student
# 30-34    Data Scientist
# 35-39    Data Scientist
# 40-44    Data Scientist
# 45-49             Other
# 50-54             Other
# 55-59             Other
# 60-69             Other
# 70+      Data Scientist
# Name: Occupation, dtype: object

# %% [markdown]
# #### The count of survey participants that use each programming language in a descending order.

# %%
filtered = survey.filter(regex='^Q7', axis=1)

pl_df = filtered.describe()

new_df = pd.DataFrame({'Count': pl_df.loc['count'].values}, index=pl_df.loc['top'])

new_df.sort_values('Count', ascending=False, inplace=True)

new_df
# Out:
#             Count
# top
# Python      15530
# SQL          7535
# R            4277
# C++          3827
# Java         3367
# C            3315
# Javascript   2995
# MATLAB       2217
# Other        1945
# Bash         1776
# Julia         262
# None          206
# Swift         198

# %% [markdown]
# #### The count of data scientist survey participants that use each programming language in a descending order.

# %%
data_scientists_df = survey.loc[survey['Occupation'] == "Data Scientist"]

data_scientists_df = data_scientists_df.filter(regex='^Q7', axis=1)

data_scientists_df = data_scientists_df.describe()

ds_df = pd.DataFrame({'Count': data_scientists_df.loc['count'].values}, index=data_scientists_df.loc['top'])

ds_df.sort_values('Count', ascending=False, inplace=True)

ds_df
# Out:
#            Count
# top
# Python      2453
# SQL         1473
# R            975
# Bash         405
# C++          323
# Java         305
# Javascript   290
# C            247
# Other        245
# MATLAB       242
# Julia         71
# Swift         14
# None           5

# %%
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(12,12))

ax1.set_title("Programming languages all respondents use")

ax2.set_title("Programming languages data scientists use")

new_df.plot.bar(ax=ax1)

ds_df.plot.bar(ax=ax2)
# Out:
# <AxesSubplot:title={'center':'Programming languages data scientists use'}, xlabel='top'>

# %% [markdown]
# #### Coding Experience of the data scientists that use machine learning methods.

# %%
df = survey.loc[survey['Occupation'] == "Data Scientist"]

df = df.loc[df['Q15'] != "I do not use machine learning methods"]

df['Coding Experience'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### List of the number of users of machine learning algorithms used only by those who use the scikit-learn framework, from large to small

# %%
sci_df = survey.filter(regex='^Q1(6|7)', axis=1).copy()

sci_df.dropna(subset=['Q16_Part_1'], inplace=True)

sci_df = sci_df.filter(regex='^Q17', axis=1)

sci_df = sci_df.describe()

sci_df = pd.DataFrame({'Count': sci_df.loc['count'].values}, index=sci_df.loc['top'])

sci_df.sort_values('Count', ascending=False, inplace=True)

sci_df
# Out:
#                                                    Count
# top
# Linear or Logistic Regression                       8382
# Decision Trees or Random Forests                    7340
# Convolutional Neural Networks                       4679
# Gradient Boosting Machines (xgboost, lightgbm, ...  4507
# Bayesian Approaches                                 2886
# Recurrent Neural Networks                           2795
# Dense Neural Networks (MLPs, etc)                   2739
# Transformer Networks (BERT, gpt-3, etc)             1064
# Generative Adversarial Networks                      792
# Evolutionary Approaches                              523
# Other                                                292
# None                                                 211

# %% [markdown]
# #### The number of people who regularly use the scikit-learn, tensorflow and keras libraries.

# %%
survey.filter(regex='^Q16', axis=1).iloc[:,:3].describe()[2:]
# Out:
#            Q16_Part_1     Q16_Part_2 Q16_Part_3
# top     Scikit-learn     TensorFlow      Keras
# freq            10250           6934       6192

# %%
import re
import statistics

def interval_to_mean(row):
    
        row = str(row).replace(",", "").replace("-", " ").replace("$", "")

        list_of_nums = list(map(int,re.findall(r'\d+', row)))

        return statistics.mean(list_of_nums)

# %%
survey['ConvertedComp'] = survey['Q24'].apply(lambda x: interval_to_mean(x) if pd.notnull(x) else x)

grouped = survey.groupby(['Occupation'])

grouped = grouped.apply(lambda x: x.ConvertedComp.mean())

grouped.sort_values(ascending=False, inplace=True)

grouped = pd.DataFrame({'Occupation': grouped.index, 'ConvertedComp': grouped.values})

print("The profession with the highest average annual salary: {}\n".format(grouped.Occupation.iloc[0]))

ds_rank = grouped.loc[grouped['Occupation'] == 'Data Scientist'].ConvertedComp.index[0]+1

print("Data Scientists ranks #{}".format(ds_rank))
# Out:
# The profession with the highest average annual salary: Product/Project Manager
#
# Data Scientists ranks #2

# %% [markdown]
# #### Average annual salary of Data Scientist employees by country in a descending order.

# %%
df= survey.loc[survey['Occupation'] == "Data Scientist"]

df = df.groupby(['Country'])

df = df.apply(lambda x: x.ConvertedComp.mean())

df.sort_values(ascending=False, inplace=True)

df.iloc[:10]
# Out:
# Country
# United States of America                                142609.330110
# Israel                                                  111979.520000
# Switzerland                                             109230.269231
# Australia                                               104318.958333
# United Kingdom of Great Britain and Northern Ireland     89749.504587
# Germany                                                  79804.195312
# Ireland                                                  78499.500000
# Singapore                                                76937.000000
# Canada                                                   74466.481132
# Thailand                                                 73707.875000
# dtype: float64

# %%
compdf = survey.loc[~survey['Q20'].isin(['0-49 employees','50-249 employees'])]

print("Average salaries of the people who works at companies that have more than 250 employees:", compdf.ConvertedComp.mean())
# Out:
# Average salaries of the people who works at companies that have more than 250 employees: 56410.82901998097

# %%
grouped = compdf.groupby('Q20')

grouped.apply(lambda x: x.ConvertedComp.mean())
# Out:
# Q20
# 10,000 or more employees    62303.713274
# 1000-9,999 employees        55084.827184
# 250-999 employees           48664.562934
# dtype: float64

# %% [markdown]
# #### Mean, standard deviation and median values of annual salary by country

# %%
group_df = survey.groupby(survey['Country'])

comp_mean = group_df['ConvertedComp'].mean()

comp_std = group_df['ConvertedComp'].std()

comp_median = group_df['ConvertedComp'].median()

stat_df = pd.DataFrame({'Country': comp_mean.index, 'mean': comp_mean.values, 'std': comp_std.values, 'median': comp_median.values})

stat_df.sort_values('mean',ascending=False, inplace=True)

stat_df.reset_index(drop=True, inplace=True)

stat_df
# Out:
#                                               Country           mean  \
# 0                            United States of America  120321.619272
# 1                                         Switzerland  120051.583333
# 2                                              Israel  109757.328125
# 3                                           Australia   87807.329932
# 4   United Kingdom of Great Britain and Northern I...   82429.511429
# 5                                             Germany   73634.271484
# 6                                              Canada   73563.896465
# 7                                         Netherlands   70603.482301
# 8                                United Arab Emirates   65777.277778
# 9                                              Sweden   60767.681818
# 10                                            Belgium   60299.514286
# 11                                          Singapore   57902.909091
# 12                                             France   49298.994924
# 13                                            Ireland   48792.357143
# 14                                              Japan   46846.254545
# 15                                              Spain   44893.730769
# 16                                       South Africa   39914.056962
# 17                                              Italy   38798.413043
# 18                                        South Korea   38490.890805
# 19                                  Republic of Korea   36130.452381
# 20                                              China   34240.475904
# 21                                       Saudi Arabia   32515.457447
# 22                                              Other   32431.712883
# 23                                             Poland   32262.255102
# 24                                           Portugal   30778.235632
# 25                                             Mexico   29053.851449
# 26                                           Thailand   27935.317568
# 27                                              Ghana   27380.476190
# 28                                            Romania   25585.026316
# 29                                             Taiwan   25027.955285
# 30                                              Chile   24358.370968
# 31                                             Greece   23341.807692
# 32                                             Brazil   22765.867946
# 33                                           Malaysia   21406.907407
# 34                                             Russia   20793.660969
# 35                                              India   18205.940926
# 36                                            Ukraine   17938.096491
# 37                                          Argentina   17818.777108
# 38                                            Tunisia   17494.510000
# 39                                             Turkey   16692.274096
# 40                                        Philippines   14847.539216
# 41                                               Peru   14281.758065
# 42                                           Colombia   13787.000000
# 43                                            Belarus   13722.472973
# 44                                          Indonesia   13336.122047
# 45                                              Nepal   12837.000000
# 46                                            Morocco   11078.666667
# 47                                           Pakistan    9966.446281
# 48                                           Viet Nam    9644.078313
# 49                                              Egypt    7923.413043
# 50                                          Sri Lanka    7808.710526
# 51                                            Nigeria    7224.095528
# 52                                              Kenya    6536.166667
# 53                       Iran, Islamic Republic of...    5788.461039
# 54                                         Bangladesh    4483.195652
#
#               std    median
# 0    85088.163171  112499.5
# 1    54795.290175  112499.5
# 2   101749.997198   94999.5
# 3    70029.059912   84999.5
# 4    77980.660312   64999.5
# 5    64869.140664   64999.5
# 6    55076.938245   74999.5
# 7    38504.894831   64999.5
# 8    57151.792062   64999.5
# 9    33930.786528   54999.5
# 10   90493.262619   34999.5
# 11   49854.218971   54999.5
# 12   43793.873375   44999.5
# 13   37363.796064   44999.5
# 14   44603.185658   44999.5
# 15   34130.190951   34999.5
# 16   43042.649654   27499.5
# 17   31039.795520   34999.5
# 18   70712.435919   17499.5
# 19   37065.994132   17499.5
# 20   76844.017511   12499.5
# 21   43122.783631    6249.5
# 22   55319.323914   12499.5
# 23   24266.172534   27499.5
# 24   30847.510955   27499.5
# 25   55745.597406   12499.5
# 26   64824.801260    9374.5
# 27  108340.591424    3499.5
# 28   21947.593933   22499.5
# 29   24085.554545   17499.5
# 30   28618.055066   19999.5
# 31   28201.201258   17499.5
# 32   41134.822702   12499.5
# 33   31333.653930   12499.5
# 34   34179.581195   12499.5
# 35   41517.116274    6249.5
# 36   20936.127089    8749.5
# 37   33887.914091   12499.5
# 38   71493.780057     499.5
# 39   43730.238109    8749.5
# 40   26443.953866    6249.5
# 41   23331.339468    3999.5
# 42   16271.387025    6249.5
# 43   17075.586026    6249.5
# 44   57363.592207    1499.5
# 45   38390.160729    3499.5
# 46   23487.802986     999.5
# 47   46414.110444    1499.5
# 48   18958.319192    2499.5
# 49   18049.829499    1499.5
# 50   13459.703901    1499.5
# 51   34293.080845     499.5
# 52   11935.191926    1499.5
# 53   18104.369608    1499.5
# 54    7027.802362    1999.5

# %%
print("Turkey ranks #{}".format(stat_df[stat_df['Country'] == "Turkey"].index[0]+1))
# Out:
# Turkey ranks #40

# %%
stat_df.loc[stat_df['Country'] == "Turkey"]
# Out:
#    Country          mean           std  median
# 39  Turkey  16692.274096  43730.238109  8749.5

# %% [markdown]
# ## Soru 9:
# Lisans, yüksek lisans ve doktora mezunlarına ilişkin (ayrı ayrı); yatay eksende kodlama deneyimi (artan sırada olmalıdır), dikey eksende ortalama maaş bilgisi olacak şekilde tek bir çizgi grafiği çiziniz.

# %%
lisans_df = survey.loc[survey['Education'] == 'Bachelor’s degree']

yuksek_lisans_df = survey.loc[survey['Education'] == 'Master’s degree']

doktora_df = survey.loc[survey['Education'] == 'Doctoral degree']

new_index = ['I have never written code', '< 1 years', '1-2 years', '3-5 years', '5-10 years', '10-20 years', '20+ years']

# %%
lisans_grup = lisans_df.groupby(['Coding Experience'])

lisans_grup = lisans_grup.apply(lambda x: x.ConvertedComp.mean())

lisans_grup = lisans_grup.reindex(new_index)

# %%
yuksek_lisans_grup = yuksek_lisans_df.groupby(['Coding Experience'])

yuksek_lisans_grup = yuksek_lisans_grup.apply(lambda x: x.ConvertedComp.mean())

yuksek_lisans_grup = yuksek_lisans_grup.reindex(new_index)

# %%
doktora_grup = doktora_df.groupby(['Coding Experience'])

doktora_grup = doktora_grup.apply(lambda x: x.ConvertedComp.mean())

doktora_grup = doktora_grup.reindex(new_index)

plt.xticks(rotation='vertical')

plt.plot(lisans_grup, label='Lisans')

plt.plot(yuksek_lisans_grup, label='Yüksek Lisans')

plt.plot(doktora_grup, label='Doktora')

plt.legend(loc=9)

# %% [markdown]
# ## Soru 10:
# * Mesleklerdeki (```Occupation```) cinsiyet dağılımını, yatay yığılmış "stacked" sütun grafik olarak gösteriniz.
# * Her meslek (```Occupation```) için kadın oranını bulup büyükten küçüğe sıralayınız.
# * Şu anda çalışmayan kadın ve erkek oranlarını listeleyiniz.

# %%
bar = survey.groupby(['Occupation','Gender'])['Occupation'].count().unstack('Gender')

bar[survey['Gender'].unique()].plot.barh(figsize=(12,12), stacked=True)
# Out:
# <AxesSubplot:ylabel='Occupation'>

# %%
bar
# Out:
# Gender                        Man  Nonbinary  Prefer not to say  \
# Occupation
# Business Analyst            620.0        2.0               11.0
# Currently not employed     1231.0        4.0               30.0
# DBA/Database Engineer       103.0        2.0                4.0
# Data Analyst               1098.0        1.0               11.0
# Data Engineer               364.0        NaN                7.0
# Data Scientist             2180.0        8.0               26.0
# Machine Learning Engineer   917.0        NaN               14.0
# Other                      1405.0        2.0               20.0
# Product/Project Manager     597.0        1.0                8.0
# Research Scientist          894.0        4.0               30.0
# Software Engineer          1661.0        4.0               28.0
# Statistician                217.0        1.0                1.0
# Student                    3812.0       18.0               52.0
#
# Gender                     Prefer to self-describe   Woman
# Occupation
# Business Analyst                               1.0   152.0
# Currently not employed                         7.0   373.0
# DBA/Database Engineer                          NaN    16.0
# Data Analyst                                   4.0   343.0
# Data Engineer                                  1.0    60.0
# Data Scientist                                 8.0   437.0
# Machine Learning Engineer                      4.0   135.0
# Other                                          4.0   289.0
# Product/Project Manager                        2.0    78.0
# Research Scientist                             2.0   237.0
# Software Engineer                              6.0   260.0
# Statistician                                   NaN    68.0
# Student                                       13.0  1232.0

# %%
bar['Sum'] = bar.apply(lambda x: x.sum(), axis=1)

print("Her meslek için kadın oranı (Yüzde)")

(bar['Woman'] / bar['Sum'] * 100).sort_values(ascending=False)
# Out:
# Her meslek için kadın oranı (Yüzde)
# Occupation
# Student                      24.029647
# Statistician                 23.693380
# Data Analyst                 23.541524
# Currently not employed       22.674772
# Research Scientist           20.308483
# Business Analyst             19.338422
# Other                        16.802326
# Data Scientist               16.434750
# Data Engineer                13.888889
# Software Engineer            13.272078
# DBA/Database Engineer        12.800000
# Machine Learning Engineer    12.616822
# Product/Project Manager      11.370262
# dtype: float64

# %%
women_count = bar.Woman.sum()
men_count = bar.Man.sum()

not_employed_women = bar.loc['Currently not employed'].Woman
not_employed_men = bar.loc['Currently not employed'].Man

print("Şu anda çalışmayan kadın oranı: %", (not_employed_women / women_count) * 100)
print("Şu anda çalışmayan erkek oranı: %", (not_employed_men / men_count) * 100)
# Out:
# Şu anda çalışmayan kadın oranı: % 10.13586956521739
# Şu anda çalışmayan erkek oranı: % 8.15285780515266

# %% [markdown]
# ## Soru 11:
#
# Ankete katılan kadınlardan ortalama çalışma süresi 3 yılın üzerinde olanlar için:
# * Kadın katılımcı sayısının en yüksek olduğu ülke hangisidir?
# * Türkiye'den ankete katılan kadınların eğitim durumlarını pasta grafiğinde gösteriniz.

# %%
women_df = survey.loc[survey['Gender'] == "Woman"]

exp_women_df = women_df.loc[~women_df['Coding Experience'].isin(['< 1 years','1-2 years'])]

grouped = exp_women_df.groupby(survey['Country'])

grouped = grouped.apply(lambda x: x.Gender.count())

print("Kadın katılımcı sayısının en yüksek olduğu ülke:",grouped.idxmax())
# Out:
# Kadın katılımcı sayısının en yüksek olduğu ülke: India

# %%
survey_tr_women = women_df.loc[women_df['Country'] == "Turkey"]

survey_tr_women['Education'].value_counts().plot(kind="pie", figsize=(6,6), autopct='%0.0f%%')
# Out:
# <AxesSubplot:ylabel='Education'>

# %% [markdown]
# ## Soru 12:
# * 39. soru ile ilgili sütunlarda yer alan değerlerdeki parantez içi ifadeleri siliniz.
# * 18-21 yaş aralığında olan katılımcıların favori sosyal medya platformu nedir?

# %%
import re

def clean(row):
    cleanr = re.compile('\(.*?\)')
    cleantext = re.sub(cleanr, '', row)
    return cleantext

# %%
q39 = survey.filter(regex='^Q39', axis=1)

survey[q39.columns] = q39.applymap(clean, na_action='ignore')

survey[q39.columns]
# Out:
#       Q39_Part_1          Q39_Part_2 Q39_Part_3 Q39_Part_4      Q39_Part_5  \
# 0            NaN                 NaN        NaN    Kaggle              NaN
# 1       Twitter                  NaN    Reddit     Kaggle   Course Forums
# 2            NaN  Email newsletters         NaN    Kaggle              NaN
# 3            NaN                 NaN        NaN        NaN             NaN
# 4            NaN                 NaN        NaN        NaN             NaN
# ...          ...                 ...        ...        ...             ...
# 20029        NaN                 NaN        NaN        NaN             NaN
# 20032        NaN                 NaN        NaN        NaN             NaN
# 20033        NaN                 NaN        NaN        NaN             NaN
# 20034   Twitter                  NaN        NaN    Kaggle              NaN
# 20035        NaN                 NaN        NaN    Kaggle   Course Forums
#
#       Q39_Part_6 Q39_Part_7 Q39_Part_8             Q39_Part_9  \
# 0            NaN        NaN        NaN  Journal Publications
# 1       YouTube         NaN     Blogs                     NaN
# 2       YouTube         NaN        NaN                    NaN
# 3            NaN        NaN        NaN                    NaN
# 4            NaN        NaN        NaN                    NaN
# ...          ...        ...        ...                    ...
# 20029   YouTube         NaN        NaN                    NaN
# 20032        NaN        NaN        NaN                    NaN
# 20033        NaN        NaN        NaN                    NaN
# 20034   YouTube         NaN     Blogs                     NaN
# 20035   YouTube   Podcasts      Blogs                     NaN
#
#               Q39_Part_10 Q39_Part_11 Q39_OTHER
# 0                     NaN         NaN       NaN
# 1      Slack Communities          NaN       NaN
# 2                     NaN         NaN       NaN
# 3                     NaN        None       NaN
# 4                     NaN         NaN       NaN
# ...                   ...         ...       ...
# 20029                 NaN         NaN       NaN
# 20032                 NaN        None       NaN
# 20033                 NaN         NaN       NaN
# 20034                 NaN         NaN       NaN
# 20035                 NaN         NaN       NaN
#
# [19120 rows x 12 columns]

# %%
youngAdult = survey.loc[survey['Age'] == '18-21']

filtered = youngAdult.filter(regex='^Q39', axis=1)

filtered = filtered.describe()

socialmediadf = pd.DataFrame({'Count': filtered.loc['count'].values}, index=filtered.loc['top'])

socialmediadf.sort_values('Count', ascending=False, inplace=True)

print("18-21 yaş aralığında olan katılımcıların favori sosyal medya platformu:",socialmediadf.index[0])
# Out:
# 18-21 yaş aralığında olan katılımcıların favori sosyal medya platformu: Kaggle

# %% [markdown]
# ## Soru 13:
# * https://download.geonames.org/export/dump/countryInfo.txt adresindeki veriyi:
#     * ilk 49 satırını ihmal ederek
#     * yalnızca ```#ISO, Country, neighbours``` sütunlarını kullanarak
#     * ```Country``` sütununu indeks sütun olarak
#
# okuyarak __country_info__ adlı DataFrame'e aktarınız.
# * ```#ISO``` sütununun ismini ```Country Code``` olarak değiştiriniz.
# * ```survey``` ve ```country_info``` adlı DataFrame'leri ülke bazında birleştirip ```merged_survey``` adında yeni bir dataframe'e aktarınız.

# %%
country_info = pd.read_csv('countryInfo.txt', delimiter = "\t", index_col='Country', usecols=['#ISO','Country','neighbours'], skiprows=49)
country_info
# Out:
#                       #ISO            neighbours
# Country
# Andorra                 AD                 ES,FR
# United Arab Emirates    AE                 SA,OM
# Afghanistan             AF     TM,CN,IR,TJ,PK,UZ
# Antigua and Barbuda     AG                   NaN
# Anguilla                AI                   NaN
# ...                    ...                   ...
# South Africa            ZA     ZW,SZ,MZ,BW,NA,LS
# Zambia                  ZM  ZW,TZ,MZ,CD,NA,MW,AO
# Zimbabwe                ZW           ZA,MZ,BW,ZM
# Serbia and Montenegro   CS  AL,HU,MK,RO,HR,BA,BG
# Netherlands Antilles    AN                    GP
#
# [252 rows x 2 columns]

# %%
country_info.rename(columns={"#ISO": "Country Code"}, inplace=True)
country_info
# Out:
#                       Country Code            neighbours
# Country
# Andorra                         AD                 ES,FR
# United Arab Emirates            AE                 SA,OM
# Afghanistan                     AF     TM,CN,IR,TJ,PK,UZ
# Antigua and Barbuda             AG                   NaN
# Anguilla                        AI                   NaN
# ...                            ...                   ...
# South Africa                    ZA     ZW,SZ,MZ,BW,NA,LS
# Zambia                          ZM  ZW,TZ,MZ,CD,NA,MW,AO
# Zimbabwe                        ZW           ZA,MZ,BW,ZM
# Serbia and Montenegro           CS  AL,HU,MK,RO,HR,BA,BG
# Netherlands Antilles            AN                    GP
#
# [252 rows x 2 columns]

# %%
merged_survey = survey.merge(country_info, on='Country', how='left')
merged_survey
# Out:
#          Age Gender                                            Country  \
# 0      35-39    Man                                           Colombia
# 1      30-34    Man                           United States of America
# 2      35-39    Man                                          Argentina
# 3      30-34    Man                           United States of America
# 4      30-34    Man                                              Japan
# ...      ...    ...                                                ...
# 19115  35-39    Man                                           Thailand
# 19116  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 19117  30-34    Man                                             Brazil
# 19118  22-24    Man                                              India
# 19119  22-24    Man                                           Pakistan
#
#                Education                 Occupation Coding Experience  \
# 0        Doctoral degree                    Student        5-10 years
# 1        Master’s degree              Data Engineer        5-10 years
# 2      Bachelor’s degree          Software Engineer       10-20 years
# 3        Master’s degree             Data Scientist        5-10 years
# 4        Master’s degree          Software Engineer         3-5 years
# ...                  ...                        ...               ...
# 19115  Bachelor’s degree                      Other       10-20 years
# 19116    Master’s degree     Currently not employed         20+ years
# 19117    Master’s degree         Research Scientist         < 1 years
# 19118  Bachelor’s degree          Software Engineer         3-5 years
# 19119    Master’s degree  Machine Learning Engineer         < 1 years
#
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4  ...   Q35_B_Part_5  \
# 0        Python         R       SQL         C  ...   TensorBoard
# 1        Python         R       SQL       NaN  ...            NaN
# 2           NaN       NaN       NaN       NaN  ...            NaN
# 3        Python       NaN       SQL       NaN  ...            NaN
# 4        Python       NaN       NaN       NaN  ...            NaN
# ...         ...       ...       ...       ...  ...            ...
# 19115       NaN       NaN       SQL         C  ...            NaN
# 19116    Python       NaN       NaN       NaN  ...            NaN
# 19117    Python       NaN       NaN       NaN  ...            NaN
# 19118    Python       NaN       SQL         C  ...   TensorBoard
# 19119    Python       NaN       NaN       NaN  ...            NaN
#
#       Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10  \
# 0              NaN          NaN          NaN          NaN           NaN
# 1              NaN          NaN          NaN          NaN           NaN
# 2              NaN          NaN          NaN          NaN          None
# 3              NaN          NaN          NaN          NaN           NaN
# 4              NaN          NaN          NaN          NaN           NaN
# ...            ...          ...          ...          ...           ...
# 19115          NaN          NaN          NaN          NaN          None
# 19116          NaN          NaN          NaN          NaN          None
# 19117          NaN          NaN          NaN          NaN           NaN
# 19118          NaN          NaN      Trains           NaN           NaN
# 19119          NaN          NaN      Trains           NaN           NaN
#
#       Q35_B_OTHER ConvertedComp Country Code                     neighbours
# 0             NaN           NaN           CO                 EC,PE,PA,BR,VE
# 1             NaN      112499.5          NaN                            NaN
# 2             NaN       17499.5           AR                 CL,BO,UY,PY,BR
# 3             NaN      137499.5          NaN                            NaN
# 4             NaN           NaN           JP                            NaN
# ...           ...           ...          ...                            ...
# 19115         NaN       17499.5           TH                    LA,MM,KH,MY
# 19116         NaN           NaN          NaN                            NaN
# 19117         NaN         499.5           BR  SR,PE,BO,UY,GY,PY,GF,VE,CO,AR
# 19118         NaN         499.5           IN              CN,NP,MM,BT,PK,BD
# 19119         NaN         499.5           PK                    CN,AF,IR,IN
#
# [19120 rows x 357 columns]

# %% [markdown]
# ## Soru 14:
# Almanya ve komşu ülkeleri için ankete katılanlardan doktoralıların ülke bazında yüzdelerini, ülke isimlerine göre alfabetik sırada listeleyiniz.

# %%
#Almanyanın komşu ülkelerinin ülke kodlarını alıyoruz
germany_neighbours = merged_survey.loc[merged_survey['Country'] == "Germany"].iloc[0].neighbours.split(',')

# %%
#Almanyayı da dahil ediyoruz
germany_neighbours.append('DE')

# %%
germany_neighbours
# Out:
# ['CH', 'PL', 'NL', 'DK', 'BE', 'CZ', 'LU', 'FR', 'AT', 'DE']

# %%
germany_neighbours_df = merged_survey.loc[merged_survey['Country Code'].isin(germany_neighbours)]

# %%
education_df = germany_neighbours_df.groupby(['Country','Education'])['Country'].count().unstack('Education')

# %%
education_df['Sum'] = education_df.apply(lambda x: x.sum(), axis=1)
education_df
# Out:
# Education    Bachelor’s degree  Doctoral degree  I prefer not to answer  \
# Country
# Belgium                    6.0             13.0                     NaN
# France                    13.0             75.0                     6.0
# Germany                   46.0             99.0                     2.0
# Netherlands               22.0             23.0                     1.0
# Poland                    21.0             22.0                     2.0
# Switzerland                8.0             22.0                     NaN
#
# Education    Master’s degree  No formal education past high school  \
# Country
# Belgium                 38.0                                   1.0
# France                 197.0                                   6.0
# Germany                201.0                                   6.0
# Netherlands            100.0                                   NaN
# Poland                  88.0                                   3.0
# Switzerland             35.0                                   1.0
#
# Education    Professional degree  \
# Country
# Belgium                      NaN
# France                      10.0
# Germany                     11.0
# Netherlands                  NaN
# Poland                       4.0
# Switzerland                  2.0
#
# Education    Some college/university study without earning a bachelor’s degree  \
# Country
# Belgium                                                    1.0
# France                                                     6.0
# Germany                                                   18.0
# Netherlands                                                3.0
# Poland                                                     5.0
# Switzerland                                                NaN
#
# Education      Sum
# Country
# Belgium       59.0
# France       313.0
# Germany      383.0
# Netherlands  149.0
# Poland       145.0
# Switzerland   68.0

# %%
print("Doktoralıların ülke bazında yüzdeleri")

(education_df['Doctoral degree'] / education_df['Sum']) * 100
# Out:
# Doktoralıların ülke bazında yüzdeleri
# Country
# Belgium        22.033898
# France         23.961661
# Germany        25.848564
# Netherlands    15.436242
# Poland         15.172414
# Switzerland    32.352941
# dtype: float64
